# %%
from scipy.io import loadmat

# %%
behav = loadmat('/Users/Rui/Downloads/110616js_1.mat')

# %%
behav
# Out:
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, Platform: MACI, Created on: Thu Jun 16 15:36:26 2011',
#  '__version__': '1.0',
#  'params': array([[ ([[800, 600]], [[1]], ['white'], [[8]], [[16]], [[178]], [[0.5, 3.0]], [[0.15]], [[0.45]], [[105]], ['/Users/jmcarp/Dropbox/experiments/tps/cyberball'], ['/Users/jmcarp/Dropbox/experiments/tps/cyberball/log'], [[128]], [[8]], [[15]], [[0, 0, 0]], [[7]], [[-200, -200], [200, -200], [0, 200]], [[300]], [[-50]], [[-50]], [[100]], [[-200]], [[-175]], ['Helvetica'], [[30]], ['110616js'], ['/Users/jmcarp/Dropbox/experiments/tps/cyberball/log/110616js_1.mat'], [[1]], ['Jesse'], ['Andrew'], ['Nick'], ['16-Jun-2011 15:27:01'], ['MACI'], ['jmcarp'], [[0]], [[255]], [[0]], [[255]], [[10]], [[0.016549505763687192]], [[400]], [[300]], [[510]], [[1318082.670449221]])]],
# ...

# %%
file = open('/Users/Rui/Downloads/TPS2063.log', 'r')

lines = file.read().splitlines()
file.close()

# %%
lines
# Out:
# ['61.8105\tWARNING\tUser requested fullscreen with size [800 600], but screen is actually [1024, 768]. Using actual size',
#  '0.0001\tDATA\tSTART',
#  '8.0079\tDATA\tDisplaying Round 1 label',
#  '10.0203\tDATA\tStarting Round 1',
#  '11.2370\tDATA\tround 1 - trial 0 - throw: 1to3 - FBALL',
#  '14.7313\tDATA\tround 1 - trial 1 - throw: 3to1 - FBALL',
#  '18.2255\tDATA\tround 1 - trial 2 - throw: 1to2 - FBALL',
#  '19.5633\tDATA\tPLAYER HAS BALL',
#  '20.9737\tDATA\tKeypress: 2',
#  '20.9748\tDATA\tPLAYER THROWS TO 1 - RT 1.4115',
#  '20.9748\tDATA\tround 1 - trial 3 - throw: 2to1 - FBALL',
#  '24.1533\tDATA\tround 1 - trial 4 - throw: 1to3 - FBALL',
#  '26.6492\tDATA\tround 1 - trial 5 - throw: 3to1 - FBALL',
#  '28.1456\tDATA\tround 1 - trial 6 - throw: 1to3 - FBALL',
#  '31.6410\tDATA\tround 1 - trial 7 - throw: 3to1 - FBALL',
#  '36.1492\tDATA\tround 1 - trial 8 - throw: 1to3 - FBALL',
#  '39.6435\tDATA\tround 1 - trial 9 - throw: 3to2 - FBALL',
# ...
